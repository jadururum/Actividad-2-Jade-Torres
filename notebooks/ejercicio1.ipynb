# %%
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way
to do it.
Although that way may not be obvious at first unless you're
Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good
idea.
Namespaces are one honking great idea -- let's do more of
those!"""

# %%
#Creo variables
lineas=text.splitlines()
lineas_totales=len(lineas)
palabras_por_linea=[len(linea.split()) for linea in lineas]
palabras_totales=sum(palabras_por_linea)
promedio_palabras_por_linea=palabras_totales/lineas_totales

# %%
#Imprimo
print(f"Total de líneas: {lineas_totales}")
print(f"Total de palabras: {palabras_totales}")
print(f"Promedio de palabras por línea: {promedio_palabras_por_linea:.2f}")
# Out:
# Total de líneas: 23
# Total de palabras: 137
# Promedio de palabras por línea: 5.96

# %%
print(f"Líneas por encima del promedio: ")

#Recorrido para imprimir las líneas con cantidad de palabras por encima del promedio
for linea in lineas:
    cantidad_de_palabras=len(linea.split())
    if cantidad_de_palabras>promedio_palabras_por_linea:
        print(f'- "{linea}" ({cantidad_de_palabras} palabras)')
# Out:
# Líneas por encima del promedio:
# - "Special cases aren't special enough to break the rules." (9 palabras)
# - "In the face of ambiguity, refuse the temptation to guess." (10 palabras)
# - "There should be one-- and preferably only one --obvious way" (10 palabras)
# - "Although that way may not be obvious at first unless you're" (11 palabras)
# - "Although never is often better than *right* now." (8 palabras)
# - "If the implementation is hard to explain, it's a bad idea." (11 palabras)
# - "If the implementation is easy to explain, it may be a good" (12 palabras)
# - "Namespaces are one honking great idea -- let's do more of" (11 palabras)
